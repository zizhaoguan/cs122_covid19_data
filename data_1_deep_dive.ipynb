# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %matplotlib inline
#from google.colab import drive
#drive._mount('/content/drive')

# %%
#@dataset{2020covidclinicaldata,
#  author =       {Carbon Health and Braid Health},
#  title =        {Coronavirus Disease 2019 (COVID-19) Clinical Data Repository},
#  howpublished = {Accessed from \url{https://covidclinicaldata.org/.}},
#  year =         2020,
#  version =      {10-20-2020}
#}

# %%
#data_files = os.listdir("/content/drive/MyDrive/CS122_Team_Mochi_Cat_Project/Data/CSV")
#data_files_path = map(lambda file: "/content/drive/MyDrive/CS122_Team_Mochi_Cat_Project/Data/CSV/"+file, data_files)

data_files_path = ["https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/04-07_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/04-14_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/04-21_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/04-28_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/05-05_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/05-12_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/05-19_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/05-26_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/06-02_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/06-09_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/06-16_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/06-23_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/06-30_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/07-07_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/07-14_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/07-21_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/07-28_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/08-04_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/08-11_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/08-18_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/08-25_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/09-01_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/09-08_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/09-15_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/09-22_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/09-29_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/10-06_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/10-13_carbonhealth_and_braidhealth.csv",
                   "https://raw.githubusercontent.com/zizhaoguan/cs122_covid19_data/main/data_1/10-20_carbonhealth_and_braidhealth.csv"]

'''
true_list = ["Positive", "True"]
false_list = ["Negative", "False"]
'''

true_list = ["True"]
false_list = ["False"]

df_list = [
           pd.read_csv(
               path,
               na_values=["-"],
               true_values = true_list,
               false_values = false_list,
               ) for path in data_files_path
           ]

combine_df = pd.concat(df_list)
combine_df
combine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93995 entries, 0 to 7293
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   batch_date                     93995 non-null  object
#  1   test_name                      93995 non-null  object
#  2   swab_type                      93995 non-null  object
#  3   covid19_test_results           93995 non-null  object
#  4   age                            93995 non-null  int64
#  5   high_risk_exposure_occupation  93826 non-null  object
#  6   high_risk_interactions         69168 non-null  object
#  7   diabetes                       93995 non-null  bool
#  8   chd                            93995 non-null  bool
#  9   htn                            93995 non-null  bool
#  10  cancer                         93995 non-null  bool
#  11  asthma                         93995 non-null  bool
# ...

# %%
combine_df[combine_df["covid19_test_results"] == "Positive"]["covid19_test_results"].value_counts()
# Out:
# Positive    1313
# Name: covid19_test_results, dtype: int64

# %%
selected_df = combine_df.drop(["batch_date", "test_name", "swab_type", 
                               "rapid_flu_results", "rapid_strep_results",
                               "rhonchi", "wheezes", "days_since_symptom_onset",
                               "cough_severity", "sob_severity","cxr_findings", 
                               "cxr_impression", "cxr_label", "cxr_link", "er_referral",
                               "ctab", ], 
                              axis="columns")

selected_df = selected_df.dropna()
selected_df.index = range(len(selected_df))
#selected_df.reset_index(inplace = True)
selected_df
# Out:
#       covid19_test_results  age  ... muscle_sore sore_throat
# 0                 Negative   46  ...       False        True
# 1                 Negative   27  ...       False       False
# 2                 Negative   42  ...       False       False
# 3                 Negative    6  ...       False       False
# 4                 Negative   41  ...       False       False
# ...                    ...  ...  ...         ...         ...
# 32410             Negative   33  ...       False       False
# 32411             Negative   25  ...       False       False
# 32412             Negative   41  ...       False        True
# 32413             Negative   47  ...       False       False
# 32414             Negative   40  ...       False       False
#
# [32415 rows x 30 columns]

# %%
from collections import defaultdict
from matplotlib import pyplot as plt

high_risk_list = list(selected_df.high_risk_exposure_occupation.dropna().unique())


symptoms_list = ["high_risk_exposure_occupation", "high_risk_interactions", "diabetes",
                 "chd", "htn", "cancer", "asthma", "copd", "autoimmune_dis", "smoker", 
              	 "labored_respiration",	"cough",	"fever",	"sob", "diarrhea",
                 "fatigue",	"headache",	"loss_of_smell",	"loss_of_taste",	"runny_nose",	
                 "muscle_sore",	"sore_throat"]

covid_results = ["Positive", "Negative"]
test_result_list = [True, False]

exposure_results_dict = defaultdict(list)

for sym_test in test_result_list:
  for result in covid_results:
    exposure_results_dict[result].append(selected_df[
                      (selected_df.covid19_test_results == result) 
                      & (selected_df["high_risk_exposure_occupation"] == sym_test)
                      ]["high_risk_exposure_occupation"].size)
  
exposure_df = pd.DataFrame(exposure_results_dict, index = test_result_list)
ax = exposure_df.plot.bar(stacked=True, rot=300)
plt.title("The results between covid test and high_risk_exposure_occupation");

# %%
exposure_df #dataframe of covid test and high_risk_exposure_occupation"
# Out:
#        Positive  Negative
# True        123      3805
# False       531     27956

# %%
interactions_results_dict = defaultdict(list)

for sym_test in test_result_list:
  for result in covid_results:
    interactions_results_dict[result].append(selected_df[
                      (selected_df.covid19_test_results == result) 
                      & (selected_df["high_risk_interactions"] == sym_test)
                      ]["high_risk_interactions"].size)
  
interactions_df = pd.DataFrame(interactions_results_dict, index = test_result_list)

ax = interactions_df.plot.bar(stacked=True, rot=300)
plt.title("The results between covid test and high_risk_interactions");

# %%
interactions_df
# Out:
#        Positive  Negative
# True        124      7271
# False       530     24490

# %%
diabetes_results_dict = defaultdict(list)

for sym_test in test_result_list:
  for result in covid_results:
    diabetes_results_dict[result].append(selected_df[
                      (selected_df.covid19_test_results == result) 
                      & (selected_df["diabetes"] == sym_test)
                      ]["diabetes"].size)
  
diabetes_df = pd.DataFrame(diabetes_results_dict, index = test_result_list)

ax = diabetes_df.plot.bar(stacked=True, rot=300)

plt.title("The results between covid test and diabetes");

# %%
diabetes_df
# Out:
#        Positive  Negative
# True         13       288
# False       641     31473

# %%
chd_results_dict = defaultdict(list)

for sym_test in test_result_list:
  for result in covid_results:
    chd_results_dict[result].append(selected_df[
                      (selected_df.covid19_test_results == result) 
                      & (selected_df["chd"] == sym_test)
                      ]["chd"].size)
  
chd_df = pd.DataFrame(chd_results_dict, index = test_result_list)
ax = chd_df.plot.bar(stacked=True, rot=300)

plt.title("The results between covid test and chd");

# %%
chd_df
# Out:
#        Positive  Negative
# True          6       153
# False       648     31608

# %%
htn_results_dict = defaultdict(list)

for sym_test in test_result_list:
  for result in covid_results:
    htn_results_dict[result].append(selected_df[
                      (selected_df.covid19_test_results == result) 
                      & (selected_df["htn"] == sym_test)
                      ]["htn"].size)
  
htn_df = pd.DataFrame(htn_results_dict, index = test_result_list)
ax = htn_df.plot.bar(stacked=True, rot=300)
plt.title("The results between covid test and htn");

# %%
htn_df
# Out:
#        Positive  Negative
# True         49      1985
# False       605     29776

# %%
cancer_results_dict = defaultdict(list)

for sym_test in test_result_list:
  for result in covid_results:
    cancer_results_dict[result].append(selected_df[
                      (selected_df.covid19_test_results == result) 
                      & (selected_df["cancer"] == sym_test)
                      ]["cancer"].size)
  
cancer_df = pd.DataFrame(cancer_results_dict, index = test_result_list)
ax = cancer_df.plot.bar(stacked=True, rot=300)
plt.title("The results between covid test and cancer");

# %%
cancer_df
# Out:
#        Positive  Negative
# True          3       119
# False       651     31642

# %%
asthma_results_dict = defaultdict(list)

for sym_test in test_result_list:
  for result in covid_results:
    asthma_results_dict[result].append(selected_df[
                      (selected_df.covid19_test_results == result) 
                      & (selected_df["asthma"] == sym_test)
                      ]["asthma"].size)
  
asthma_df = pd.DataFrame(asthma_results_dict, index = test_result_list)
ax = asthma_df.plot.bar(stacked=True, rot=300)
plt.title("The results between covid test and asthma");

# %%
asthma_df
# Out:
#        Positive  Negative
# True         21      1284
# False       633     30477

# %%
copd_results_dict = defaultdict(list)

for sym_test in test_result_list:
  for result in covid_results:
    copd_results_dict[result].append(selected_df[
                      (selected_df.covid19_test_results == result) 
                      & (selected_df["copd"] == sym_test)
                      ]["copd"].size)
  
copd_df = pd.DataFrame(copd_results_dict, index = test_result_list)
ax = copd_df.plot.bar(stacked=True, rot=300)
plt.title("The results between covid test and copd");

# %%
copd_df
# Out:
#        Positive  Negative
# True          0        25
# False       654     31736

# %%
autoimmune_dis_results_dict = defaultdict(list)

for sym_test in test_result_list:
  for result in covid_results:
    autoimmune_dis_results_dict[result].append(selected_df[
                      (selected_df.covid19_test_results == result) 
                      & (selected_df["autoimmune_dis"] == sym_test)
                      ]["autoimmune_dis"].size)
  
autoimmune_dis_df = pd.DataFrame(autoimmune_dis_results_dict, index = test_result_list)
ax = autoimmune_dis_df.plot.bar(stacked=True, rot=300)
plt.title("The results between covid test and autoimmune_dis");

# %%
autoimmune_dis_df
# Out:
#        Positive  Negative
# True          1       111
# False       653     31650

# %%
smoker_results_dict = defaultdict(list)

for sym_test in test_result_list:
  for result in covid_results:
    smoker_results_dict[result].append(selected_df[
                      (selected_df.covid19_test_results == result) 
                      & (selected_df["smoker"] == sym_test)
                      ]["smoker"].size)
  
smoker_df = pd.DataFrame(smoker_results_dict, index = test_result_list)
ax = smoker_df.plot.bar(stacked=True, rot=300)
plt.title("The results between covid test and smoker");

# %%
smoker_df
# Out:
#        Positive  Negative
# True         37      1965
# False       617     29796

# %%
'''
ctab_results_dict = defaultdict(list)

for sym_test in test_result_list:
  for result in covid_results:
    ctab_results_dict[result].append(selected_df[
                      (selected_df.covid19_test_results == result) 
                      & (selected_df["ctab"] == sym_test)
                      ]["ctab"].size)
  
ctab_df = pd.DataFrame(ctab_results_dict, index = test_result_list)
ax = ctab_df.plot.bar(stacked=True, rot=300)
plt.title("The results between covid test and ctab");
'''
# Out:
# '\nctab_results_dict = defaultdict(list)\n\nfor sym_test in test_result_list:\n  for result in covid_results:\n    ctab_results_dict[result].append(selected_df[\n                      (selected_df.covid19_test_results == result) \n                      & (selected_df["ctab"] == sym_test)\n                      ]["ctab"].size)\n  \nctab_df = pd.DataFrame(ctab_results_dict, index = test_result_list)\nax = ctab_df.plot.bar(stacked=True, rot=300)\nplt.title("The results between covid test and ctab");\n'

# %%
#ctab_df

# %%
labored_respiration_results_dict = defaultdict(list)

for sym_test in test_result_list:
  for result in covid_results:
    labored_respiration_results_dict[result].append(selected_df[
                      (selected_df.covid19_test_results == result) 
                      & (selected_df["labored_respiration"] == sym_test)
                      ]["labored_respiration"].size)
  
labored_respiration_df = pd.DataFrame(labored_respiration_results_dict, index = test_result_list)
ax = labored_respiration_df.plot.bar(stacked=True, rot=300)
plt.title("The results between covid test and labored_respiration");

# %%
labored_respiration_df
# Out:
#        Positive  Negative
# True          4        36
# False       650     31725

# %%
cough_results_dict = defaultdict(list)

for sym_test in test_result_list:
  for result in covid_results:
    cough_results_dict[result].append(selected_df[
                      (selected_df.covid19_test_results == result) 
                      & (selected_df["cough"] == sym_test)
                      ]["cough"].size)
  
cough_df = pd.DataFrame(cough_results_dict, index = test_result_list)
ax = cough_df.plot.bar(stacked=True, rot=300)
plt.title("The results between covid test and cough");

# %%
cough_df
# Out:
#        Positive  Negative
# True        228      2706
# False       426     29055

# %%
fever_results_dict = defaultdict(list)

for sym_test in test_result_list:
  for result in covid_results:
    fever_results_dict[result].append(selected_df[
                      (selected_df.covid19_test_results == result) 
                      & (selected_df["fever"] == sym_test)
                      ]["fever"].size)
  
fever_df = pd.DataFrame(fever_results_dict, index = test_result_list)
ax = fever_df.plot.bar(stacked=True, rot=300)
plt.title("The results between covid test and fever");

# %%
fever_df
# Out:
#        Positive  Negative
# True        123       991
# False       531     30770

# %%
sob_results_dict = defaultdict(list)

for sym_test in test_result_list:
  for result in covid_results:
    sob_results_dict[result].append(selected_df[
                      (selected_df.covid19_test_results == result) 
                      & (selected_df["sob"] == sym_test)
                      ]["sob"].size)
  
sob_df = pd.DataFrame(sob_results_dict, index = test_result_list)
ax = sob_df.plot.bar(stacked=True, rot=300)
plt.title("The results between covid test and sob");

# %%
sob_df
# Out:
#        Positive  Negative
# True         62      1283
# False       592     30478

# %%
diarrhea_results_dict = defaultdict(list)

for sym_test in test_result_list:
  for result in covid_results:
    diarrhea_results_dict[result].append(selected_df[
                      (selected_df.covid19_test_results == result) 
                      & (selected_df["diarrhea"] == sym_test)
                      ]["diarrhea"].size)
  
diarrhea_df = pd.DataFrame(diarrhea_results_dict, index = test_result_list)
ax = diarrhea_df.plot.bar(stacked=True, rot=300)
plt.title("The results between covid test and diarrhea");

# %%
diarrhea_df
# Out:
#        Positive  Negative
# True         47       924
# False       607     30837

# %%
fatigue_results_dict = defaultdict(list)

for sym_test in test_result_list:
  for result in covid_results:
    fatigue_results_dict[result].append(selected_df[
                      (selected_df.covid19_test_results == result) 
                      & (selected_df["fatigue"] == sym_test)
                      ]["fatigue"].size)
  
fatigue_df = pd.DataFrame(fatigue_results_dict, index = test_result_list)
ax = fatigue_df.plot.bar(stacked=True, rot=300)
plt.title("The results between covid test and fatigue");

# %%
fatigue_df
# Out:
#        Positive  Negative
# True        133      3156
# False       521     28605

# %%
headache_results_dict = defaultdict(list)

for sym_test in test_result_list:
  for result in covid_results:
    headache_results_dict[result].append(selected_df[
                      (selected_df.covid19_test_results == result) 
                      & (selected_df["headache"] == sym_test)
                      ]["headache"].size)
  
headache_df = pd.DataFrame(headache_results_dict, index = test_result_list)
ax = exposure_df.plot.bar(stacked=True, rot=300)
plt.title("The results between covid test and headache");

# %%
headache_df
# Out:
#        Positive  Negative
# True        167      2707
# False       487     29054

# %%
loss_of_smell_results_dict = defaultdict(list)

for sym_test in test_result_list:
  for result in covid_results:
    loss_of_smell_results_dict[result].append(selected_df[
                      (selected_df.covid19_test_results == result) 
                      & (selected_df["loss_of_smell"] == sym_test)
                      ]["loss_of_smell"].size)
  
loss_of_smell_df = pd.DataFrame(loss_of_smell_results_dict, index = test_result_list)
ax = loss_of_smell_df.plot.bar(stacked=True, rot=300)
plt.title("The results between covid test and loss_of_smell");

# %%
loss_of_smell_df
# Out:
#        Positive  Negative
# True         80       243
# False       574     31518

# %%
runny_nose_results_dict = defaultdict(list)

for sym_test in test_result_list:
  for result in covid_results:
    runny_nose_results_dict[result].append(selected_df[
                      (selected_df.covid19_test_results == result) 
                      & (selected_df["runny_nose"] == sym_test)
                      ]["runny_nose"].size)
  
runny_nose_df = pd.DataFrame(runny_nose_results_dict, index = test_result_list)
ax = runny_nose_df.plot.bar(stacked=True, rot=300)
plt.title("The results between covid test and runny_nose");

# %%
runny_nose_df
# Out:
#        Positive  Negative
# True         86      1737
# False       568     30024

# %%
muscle_sore_results_dict = defaultdict(list)

for sym_test in test_result_list:
  for result in covid_results:
    muscle_sore_results_dict[result].append(selected_df[
                      (selected_df.covid19_test_results == result) 
                      & (selected_df["muscle_sore"] == sym_test)
                      ]["muscle_sore"].size)
  
muscle_sore_df = pd.DataFrame(muscle_sore_results_dict, index = test_result_list)
ax = muscle_sore_df.plot.bar(stacked=True, rot=300)
plt.title("The results between covid test and muscle_sore");

# %%
muscle_sore_df
# Out:
#        Positive  Negative
# True        137      1650
# False       517     30111

# %%
sore_throat_results_dict = defaultdict(list)

for sym_test in test_result_list:
  for result in covid_results:
    sore_throat_results_dict[result].append(selected_df[
                      (selected_df.covid19_test_results == result) 
                      & (selected_df["sore_throat"] == sym_test)
                      ]["sore_throat"].size)
  
sore_throat_df = pd.DataFrame(sore_throat_results_dict, index = test_result_list)
ax = sore_throat_df.plot.bar(stacked=True, rot=300)
plt.title("The results between covid test and sore_throat");

# %%
sore_throat_df
# Out:
#        Positive  Negative
# True        129      3172
# False       525     28589

# %% [markdown]
# graph the relationship: temperature,	pulse,	sys,	dia, rr,	sats

# %%
sns.catplot(
    data = selected_df,
    x = "covid19_test_results",
    y = "temperature",
    kind="violin"
)
plt.title("Distribution of Temperature for Positive and Negative Test Result");

# %%
g = sns.catplot(
    data = selected_df,
    x = "covid19_test_results",
    y = "pulse",
    kind="violin"
)
plt.title("Distribution of Pulse for Positive and Negative Test Result");

# %%
g = sns.catplot(
    data = selected_df,
    x = "covid19_test_results",
    y = "sys",
    kind="violin"
)
plt.title("Distribution of sys for Positive and Negative Test Result");

# %%
g = sns.catplot(
    data = selected_df,
    x = "covid19_test_results",
    y = "dia",
    kind="violin"
)
plt.title("Distribution of dia for Positive and Negative Test Result");

# %%
g = sns.catplot(
    data = selected_df,
    x = "covid19_test_results",
    y = "rr",
    kind="violin"
)
plt.title("Distribution of rr for Positive and Negative Test Result");

# %%
g = sns.catplot(
    data = selected_df,
    x = "covid19_test_results",
    y = "sats",
    kind="violin"
)
plt.title("Distribution of sats for Positive and Negative Test Result");

# %% [markdown]
# Base on the graphs, I chose the one with higher true positive rate and true negative rate or the one that is very easy to distinguish.

# %%
#select exposure, cough, fever, fatigue, headache, muscle_sore, sore_throat, temperature, rr, sats

select_df_1 =selected_df[["covid19_test_results", "high_risk_exposure_occupation", "cough",
                          "fever", "fatigue", "headache", "muscle_sore",
                          "sore_throat", "temperature", "rr", "sats"]]

select_df_1
# Out:
#       covid19_test_results high_risk_exposure_occupation  ...    rr   sats
# 0                 Negative                          True  ...  18.0  100.0
# 1                 Negative                          True  ...  18.0   98.0
# 2                 Negative                          True  ...  16.0  100.0
# 3                 Negative                         False  ...  20.0   98.0
# 4                 Negative                          True  ...  12.0   97.0
# ...                    ...                           ...  ...   ...    ...
# 32410             Negative                         False  ...  16.0   95.0
# 32411             Negative                         False  ...  16.0   97.0
# 32412             Negative                         False  ...  14.0   98.0
# 32413             Negative                         False  ...  16.0   98.0
# 32414             Negative                         False  ...  16.0  100.0
#
# [32415 rows x 11 columns]

# %%
change_col_list = ["high_risk_exposure_occupation", "cough", "fever", "fatigue",
                   "headache", "muscle_sore", "sore_throat"]

def change_value(row):
  for col in change_col_list:
    if row[col] == True or row[col] == "Positive":
      row[col] = 1
    elif row[col] == False or row[col] == "Negative":
      row[col] = 0
  return row

data = select_df_1.apply(change_value, axis="columns")
data
# Out:
#       covid19_test_results  high_risk_exposure_occupation  ...    rr   sats
# 0                 Negative                              1  ...  18.0  100.0
# 1                 Negative                              1  ...  18.0   98.0
# 2                 Negative                              1  ...  16.0  100.0
# 3                 Negative                              0  ...  20.0   98.0
# 4                 Negative                              1  ...  12.0   97.0
# ...                    ...                            ...  ...   ...    ...
# 32410             Negative                              0  ...  16.0   95.0
# 32411             Negative                              0  ...  16.0   97.0
# 32412             Negative                              0  ...  14.0   98.0
# 32413             Negative                              0  ...  16.0   98.0
# 32414             Negative                              0  ...  16.0  100.0
#
# [32415 rows x 11 columns]
